# %% [markdown]
# # Training an Ensemble of probabilistic MC dropouts
#
# This tutorial shows the data preprocessing and model training process for the case of an ensemble of probabilistic MC dropouts.
#
# Important note: The models are trained using `train` data and the hyperparameters should be fine-tuned using `dev_in`.

# %%
import json
import torch

print("Torch Version", torch.__version__)
# Out:
# Torch Version 1.10.2+cu102

# %%
from src.utils.auxiliary_functions import load_data_and_set_index
from src.utils.plot_utils import plot_learning_curve
from src.utils.scaler import FeatureScaler
from src.models.mc_dropout import *

# %% [markdown]
# # Load data

# %% [markdown]
# This tutorial assumes that all data files are placed in a local directory named `../datasets/`.

# %%
data_dir = "../datasets/"

# %%
train_data = load_data_and_set_index(filepath=data_dir + "train.csv", index_column_name="time_id")
dev_in_data = load_data_and_set_index(filepath=data_dir + "dev_in.csv", index_column_name="time_id")

print("Train records: ", train_data.shape[0])
print("Dev in records: ", dev_in_data.shape[0])
# Out:
# Train records:  530706
# Dev in records:  18368

# %% [markdown]
# # Data scaling

# %%
input_features = ["draft_aft_telegram",
                  "draft_fore_telegram",

                  "stw",
                  "diff_speed_overground",

                  "awind_vcomp_provider",
                  "awind_ucomp_provider",
                  "rcurrent_vcomp",
                  "rcurrent_ucomp",
                  "comb_wind_swell_wave_height",

                  "timeSinceDryDock",
                  ]

target = "power"

scaling_config = {target: "zeta",
                  "draft_aft_telegram": "zeta",
                  "draft_fore_telegram": "zeta",
                  "stw": "zeta",
                  "diff_speed_overground": "zeta",
                  "awind_vcomp_provider": "zeta",
                  "awind_ucomp_provider": "zeta",
                  "rcurrent_vcomp": "zeta",
                  "rcurrent_ucomp": "zeta",
                  "comb_wind_swell_wave_height": "zeta",
                  "timeSinceDryDock": "time"}

# %%
scaler = FeatureScaler(config=scaling_config)
scaler.fit(train_data)

train_ds = VPowerDataset(data=train_data,
                         scaler=scaler,
                         input_features=input_features,
                         target=target)
val_ds = VPowerDataset(data=dev_in_data,
                       scaler=scaler,
                       input_features=input_features,
                       target=target)

# %%
train_ds.norm_df.describe()
# Out:
#               power  draft_aft_telegram  draft_fore_telegram           stw  \
# count  5.307060e+05        5.307060e+05         5.307060e+05  5.307060e+05
# mean   1.011109e-16       -1.792227e-11         6.768778e-12 -2.022219e-16
# std    1.000000e+00        1.000000e+00         1.000000e+00  1.000000e+00
# min   -2.372240e+00       -3.048429e+00        -3.503600e+00 -4.201170e+00
# 25%   -9.651075e-01       -7.589000e-01        -7.674321e-01 -7.325259e-01
# 50%    2.860689e-01        2.166385e-01         2.406296e-01  3.744020e-01
# 75%    6.925896e-01        7.674528e-01         8.166648e-01  6.764622e-01
# max    2.773026e+00        1.630174e+00         1.565511e+00  2.250746e+00
#
#        diff_speed_overground  awind_vcomp_provider  awind_ucomp_provider  \
# count           5.307060e+05          5.307060e+05          5.307060e+05
# mean           -7.410876e-16         -1.581787e-14          4.059819e-14
# std             1.000000e+00          1.000000e+00          1.000000e+00
# min            -1.183390e+01         -3.245963e+00         -1.320819e+00
# 25%            -5.351493e-01         -7.487325e-01         -8.111294e-01
# 50%            -2.747418e-03         -2.102703e-02         -2.452139e-01
# 75%             5.888102e-01          7.463498e-01          6.283914e-01
# max             1.182840e+01          2.728355e+00          2.864781e+00
#
#        rcurrent_vcomp  rcurrent_ucomp  comb_wind_swell_wave_height  \
# count    5.307060e+05    5.307060e+05                 5.307060e+05
# mean    -2.819110e-16   -7.454790e-17                 2.773867e-14
# std      1.000000e+00    1.000000e+00                 1.000000e+00
# min     -4.246077e+00   -5.791053e+00                -1.807258e+00
# 25%     -4.072123e-01   -4.385619e-01                -6.912824e-01
# 50%      1.641387e-02   -1.809511e-02                -1.126555e-01
# 75%      4.111297e-01    4.229756e-01                 5.613785e-01
# max      4.208834e+00    5.817410e+00                 4.369962e+00
#
#        timeSinceDryDock
# count     530706.000000
# mean           0.224662
# std            0.105628
# min            0.002492
# 25%            0.149662
# 50%            0.237851
# 75%            0.314234
# max            0.401345

# %%
val_ds.norm_df.describe()
# Out:
#               power  draft_aft_telegram  draft_fore_telegram           stw  \
# count  18368.000000        18368.000000         18368.000000  18368.000000
# mean       0.006483            0.004616             0.004437      0.004487
# std        1.005389            1.001647             0.998130      1.001448
# min       -2.348383           -3.048429            -3.503600     -4.171030
# 25%       -0.957615           -0.758900            -0.623423     -0.729084
# 50%        0.290887            0.216639             0.240630      0.381766
# 75%        0.694147            0.767453             0.787863      0.680641
# max        2.352167            1.630174             1.565511      2.192417
#
#        diff_speed_overground  awind_vcomp_provider  awind_ucomp_provider  \
# count           18368.000000          18368.000000          18368.000000
# mean                0.006541              0.001634              0.002644
# std                 1.041296              1.003234              0.997360
# min               -11.833899             -3.270619             -1.320747
# 25%                -0.357682             -0.752625             -0.804838
# 50%                -0.002747             -0.021023             -0.237002
# 75%                 0.588810              0.748325              0.623145
# max                11.828405              2.665629              2.863883
#
#        rcurrent_vcomp  rcurrent_ucomp  comb_wind_swell_wave_height  \
# count    18368.000000    18368.000000                 18368.000000
# mean         0.003869       -0.007432                    -0.003090
# std          0.985902        1.011315                     1.003468
# min         -4.202029       -5.773707                    -1.807257
# 25%         -0.400807       -0.442679                    -0.693037
# 50%          0.017302       -0.020065                    -0.115562
# 75%          0.407102        0.429664                     0.551612
# max          4.190159        5.643564                     4.356416
#
#        timeSinceDryDock
# count      18368.000000
# mean           0.224919
# std            0.105971
# min            0.002498
# 25%            0.149464
# 50%            0.239435
# 75%            0.314857
# max            0.401337

# %% [markdown]
# # Model training

# %% [markdown]
# This tutorial assumes that the trained models and their histories are stored in a local directory named `../my_models/ens_mc_dropout`.

# %%
# Model directory to store data
model_dir = "../my_models/ens_mc_dropout"

# %%
models_hs = {}

for i in range(1, 11):
    store_path = os.path.join(model_dir, f"member_{i}/")
    if not os.path.exists(store_path):
        os.makedirs(store_path)

    model = ProbMCdropoutDNN(input_size=len(input_features),
                             hidden_size_1=50,
                             hidden_size_2=20,
                             dropout=0.005)
    optimizer = torch.optim.Adam(params=model.parameters(), lr=0.0001)

    history = train(model=model,
                    train_dataset=train_ds,
                    val_dataset=val_ds,
                    optimizer=optimizer,
                    store_path=store_path,
                    batch_size=32,
                    n_epochs=200,
                    es_monitor="val_mae",
                    patience=4)
    models_hs[i] = history

    with open(os.path.join(store_path, f"history.json"), 'w') as jsonfile:
        json.dump(history, jsonfile)
# Out:
# Epoch 0/200
# Average train loss: -0.12201585001908838
# Average val loss: -0.37063538229242227
# Val MSE: 0.06530205321981725
# Val MAE: 0.1926992315448535
# Saved to ../my_models/ens_mc_dropout/member_1//best_model.pth
# Epoch
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 8/200
# Average train loss: -0.5463267852785557
# Average val loss: -0.5792895155838765
# Val MSE: 0.05223428784343917
# Val MAE: 0.16360186551817618
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 9/200
# Average train loss: -0.5555754470166391
# Average val loss: -0.5891451631844666
# Val MSE: 0.05079868148431468
# Val MAE: 0.162247236428672
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 10/200
# Average train loss: -0.5647473281739633
# Average val loss: -0.593169282359243
# Val MSE: 0.04958570155376757
# Val MAE: 0.1605451311072406
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 11/200
# Average train loss: -0.5720694609154842
# Average val loss: -0.6068191680739202
# Val MSE: 0.04671724360413486
# Val MAE: 0.15544627255107882
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 12/200
# Average train loss: -0.578438557919372
# Average val loss: -0.610237904876237
# Val MSE: 0.0492742753624981
# Val MAE: 0.1600212562206211
# Epoch 13/200
# Average train loss: -0.5853236393369049
# Average val loss: -0.6116352833236344
# Val MSE: 0.049779033483872484
# Val MAE: 0.15966294147074223
# Epoch 14/200
# Average train loss: -0.5909621018951184
# Average val loss: -0.6269693809499776
# Val MSE: 0.048922696746301675
# Val MAE: 0.15822595156054256
# Epoch 15/200
# Average train loss: -0.5961284926858047
# Average val loss: -0.6325223476979687
# Val MSE: 0.04660083207817755
# Val MAE: 0.15454753499984325
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 16/200
# Average train loss: -0.6006573943740764
# Average val loss: -0.6366238243365173
# Val MSE: 0.045391340329529205
# Val MAE: 0.1525877376349857
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 17/200
# Average train loss: -0.6041658251335463
# Average val loss: -0.6420050525927481
# Val MSE: 0.04743656220290979
# Val MAE: 0.15589904974665791
# Epoch 18/200
# Average train loss: -0.6074757546783931
# Average val loss: -0.6407447097375211
# Val MSE: 0.046831534903671736
# Val MAE: 0.15552405359463617
# Epoch 19/200
# Average train loss: -0.612261626704795
# Average val loss: -0.6499006773770271
# Val MSE: 0.04686888534728217
# Val MAE: 0.15353809345760205
# Epoch 20/200
# Average train loss: -0.6153591632510583
# Average val loss: -0.6456470256995812
# Val MSE: 0.04466403127187143
# Val MAE: 0.15099996043440564
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 21/200
# Average train loss: -0.6182964571650296
# Average val loss: -0.6443850904352677
# Val MSE: 0.04945629656814584
# Val MAE: 0.1595002642284287
# Epoch 22/200
# Average train loss: -0.6211739354383651
# Average val loss: -0.6596632072968143
# Val MSE: 0.044408944363621444
# Val MAE: 0.1490983632733909
# Saved to ../my_models/ens_mc_dropout/member_4//best_model.pth
# Epoch 23/200
# Average train loss: -0.6251810706629652
# Average val loss: -0.6597023925091747
# Val MSE: 0.04604119366158176
# Val MAE: 0.15274040914345077
# Epoch 24/200
# Average train loss: -0.6274935249907445
# Average val loss: -0.6611881158817624
# Val MSE: 0.04703660874192697
# Val MAE: 0.1538054400126901
# Epoch 25/200
# Average train loss: -0.6299474392271578
# Average val loss: -0.6643322274374421
# Val MSE: 0.046096948405422715
# Val MAE: 0.15304886584757513
# Epoch 26/200
# Average train loss: -0.6320732431371132
# Average val loss: -0.6616273810989661
# Val MSE: 0.047400731789694533
# Val MAE: 0.1536093126424306
# Early stopping
# Epoch 0/200
# Average train loss: -0.08090085938431374
# Average val loss: -0.37468108566614183
# Val MSE: 0.06498809257613086
# Val MAE: 0.19344996270246623
# Saved to ../my_models/ens_mc_dropout/member_5//best_model.pth
# Epoch
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 4/200
# Average train loss: -0.47418643124974347
# Average val loss: -0.5155301402916788
# Val MSE: 0.06734967374044895
# Val MAE: 0.17492916122182736
# Epoch 5/200
# Average train loss: -0.4956627869374886
# Average val loss: -0.5376574189827261
# Val MSE: 0.06425360630376699
# Val MAE: 0.1708106078233453
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 6/200
# Average train loss: -0.5124948981128473
# Average val loss: -0.5501417042979587
# Val MSE: 0.062287669017171095
# Val MAE: 0.1690749158297474
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 7/200
# Average train loss: -0.5286826946973388
# Average val loss: -0.5685981356373336
# Val MSE: 0.05856529177484534
# Val MAE: 0.1658074296816197
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 8/200
# Average train loss: -0.5383983323512835
# Average val loss: -0.5819616959355641
# Val MSE: 0.05446760787446869
# Val MAE: 0.16123723833844428
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 9/200
# Average train loss: -0.5484730221500707
# Average val loss: -0.5866779803723512
# Val MSE: 0.059168757991670574
# Val MAE: 0.16340067098728456
# Epoch 10/200
# Average train loss: -0.5559207693209554
# Average val loss: -0.5890306606694069
# Val MSE: 0.05676222890891291
# Val MAE: 0.16434756395137684
# Epoch 11/200
# Average train loss: -0.564019648640683
# Average val loss: -0.5925244763169035
# Val MSE: 0.05568729715830669
# Val MAE: 0.16508738917885965
# Epoch 12/200
# Average train loss: -0.5713114745619563
# Average val loss: -0.6043445124397969
# Val MSE: 0.0513273616141286
# Val MAE: 0.15975564317810204
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 13/200
# Average train loss: -0.5763132156453238
# Average val loss: -0.6119853321767902
# Val MSE: 0.04966265384029948
# Val MAE: 0.15746484073820013
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 14/200
# Average train loss: -0.5797986109138775
# Average val loss: -0.6159436325007199
# Val MSE: 0.05180593419865501
# Val MAE: 0.1581028020820655
# Epoch 15/200
# Average train loss: -0.5850929465944513
# Average val loss: -0.6190473021588934
# Val MSE: 0.0527342703543889
# Val MAE: 0.1592656681346561
# Epoch 16/200
# Average train loss: -0.5902313053789882
# Average val loss: -0.6257972761157913
# Val MSE: 0.04838679950986097
# Val MAE: 0.1554844393832966
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 17/200
# Average train loss: -0.5954007336517747
# Average val loss: -0.6290391279248203
# Val MSE: 0.05038127611400981
# Val MAE: 0.1578418449514938
# Epoch 18/200
# Average train loss: -0.5985984767523513
# Average val loss: -0.6292052159721895
# Val MSE: 0.049867876387567935
# Val MAE: 0.15919825106937088
# Epoch 19/200
# Average train loss: -0.6025525073816492
# Average val loss: -0.6343146542327329
# Val MSE: 0.05138563949984696
# Val MAE: 0.15721448913268513
# Epoch 20/200
# Average train loss: -0.6071209819095121
# Average val loss: -0.6419552810658873
# Val MSE: 0.04999712451916019
# Val MAE: 0.15455441770731157
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 21/200
# Average train loss: -0.6118174621236182
# Average val loss: -0.6468896815741519
# Val MSE: 0.04737261313951545
# Val MAE: 0.1542879200900681
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 22/200
# Average train loss: -0.6141016529072811
# Average val loss: -0.6451834326136195
# Val MSE: 0.047097283989054765
# Val MAE: 0.1547967786754673
# Epoch 23/200
# Average train loss: -0.6168066513807453
# Average val loss: -0.6523653523873162
# Val MSE: 0.04578636656677552
# Val MAE: 0.15224544012769797
# Saved to ../my_models/ens_mc_dropout/member_6//best_model.pth
# Epoch 24/200
# Average train loss: -0.6207700634255605
# Average val loss: -0.6535942547659321
# Val MSE: 0.05159190879122254
# Val MAE: 0.1581264374849065
# Epoch 25/200
# Average train loss: -0.6257106956461754
# Average val loss: -0.6587862987136176
# Val MSE: 0.04753906301219497
# Val MAE: 0.15403676218635529
# Epoch 26/200
# Average train loss: -0.6243894354033432
# Average val loss: -0.6632965759403406
# Val MSE: 0.04705132662403018
# Val MAE: 0.15332543888885386
# Epoch 27/200
# Average train loss: -0.630663286561002
# Average val loss: -0.6666980054138637
# Val MSE: 0.049468470959622375
# Val MAE: 0.15428570606048098
# Early stopping
# Epoch 0/200
# Average train loss: -0.12944983917246086
# Average val loss: -0.38051305873845204
# Val MSE: 0.06483023772859875
# Val MAE: 0.19437211118508715
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 1/200
# Average train loss: -0.36922854260533566
# Average val loss: -0.44218424601214273
# Val MSE: 0.06043869512843598
# Val MAE: 0.18405708334431414
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 2/200
# Average train loss: -0.42831633526394985
# Average val loss: -0.4862417104890901
# Val MSE: 0.05804687759024497
# Val MAE: 0.17572538922005415
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 3/200
# Average train loss: -0.4659033509902937
# Average val loss: -0.5197990433789972
# Val MSE: 0.05549183340567953
# Val MAE: 0.17022096679808787
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 4/200
# Average train loss: -0.4963764742603045
# Average val loss: -0.5440821262913714
# Val MSE: 0.054452149384048236
# Val MAE: 0.168219159509766
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 5/200
# Average train loss: -0.5170795942678316
# Average val loss: -0.5569274130598594
# Val MSE: 0.053258378866683526
# Val MAE: 0.16562595987491283
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 6/200
# Average train loss: -0.5333480450481104
# Average val loss: -0.5697449948638678
# Val MSE: 0.052722509778413
# Val MAE: 0.16492258338744425
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 7/200
# Average train loss: -0.5451191298620939
# Average val loss: -0.5811848675390828
# Val MSE: 0.04842622009777701
# Val MAE: 0.15931887030341899
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 8/200
# Average train loss: -0.5562010016849387
# Average val loss: -0.592444380297478
# Val MSE: 0.04981329662559833
# Val MAE: 0.16014165766147787
# Epoch 9/200
# Average train loss: -0.56388420849614
# Average val loss: -0.5936604217149135
# Val MSE: 0.05010861165266653
# Val MAE: 0.16124511813219208
# Epoch 10/200
# Average train loss: -0.5691515085652116
# Average val loss: -0.6027164696310144
# Val MSE: 0.04983689397563736
# Val MAE: 0.16011279283370497
# Epoch 11/200
# Average train loss: -0.575093702702169
# Average val loss: -0.6059293925262442
# Val MSE: 0.04824934627549262
# Val MAE: 0.15795620398446658
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 12/200
# Average train loss: -0.5816670155183563
# Average val loss: -0.6163132815014973
# Val MSE: 0.04816178592791592
# Val MAE: 0.158547910988227
# Epoch 13/200
# Average train loss: -0.5875261925291163
# Average val loss: -0.619179124444178
# Val MSE: 0.04788616970741232
# Val MAE: 0.15658225070438525
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 14/200
# Average train loss: -0.5925052166752178
# Average val loss: -0.6244169848773122
# Val MSE: 0.04551297240202617
# Val MAE: 0.15257060785456608
# Saved to ../my_models/ens_mc_dropout/member_7//best_model.pth
# Epoch 15/200
# Average train loss: -0.596142677823966
# Average val loss: -0.6297103755130637
# Val MSE: 0.04786930727376521
# Val MAE: 0.15607614760718694
# Epoch 16/200
# Average train loss: -0.6017468736166421
# Average val loss: -0.6310090280692856
# Val MSE: 0.04744777558631027
# Val MAE: 0.15682989506226175
# Epoch 17/200
# Average train loss: -0.6066280804149962
# Average val loss: -0.6346366258292664
# Val MSE: 0.0476682136331779
# Val MAE: 0.15479330158425747
# Epoch 18/200
# Average train loss: -0.6107926614591523
# Average val loss: -0.6413432849012964
# Val MSE: 0.04770735040500124
# Val MAE: 0.15601550472270737
# Early stopping
# Epoch 0/200
# Average train loss: -0.09148069579566427
# Average val loss: -0.3523017927770623
# Val MSE: 0.06674668384806776
# Val MAE: 0.19759979614345455
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 1/200
# Average train loss: -0.33744881275927835
# Average val loss: -0.429209039997608
# Val MSE: 0.05927179133412445
# Val MAE: 0.18338449545957486
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 2/200
# Average train loss: -0.40391175027859205
# Average val loss: -0.4649262066138746
# Val MSE: 0.062440054178017255
# Val MAE: 0.18200491447949244
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 3/200
# Average train loss: -0.4438939046029328
# Average val loss: -0.4955194240098475
# Val MSE: 0.059296204649294866
# Val MAE: 0.17442679658324461
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 4/200
# Average train loss: -0.4734437138633957
# Average val loss: -0.5154452751770304
# Val MSE: 0.06258235452696681
# Val MAE: 0.17422482349264082
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 5/200
# Average train loss: -0.496397815270752
# Average val loss: -0.5387562624493595
# Val MSE: 0.05890954689135717
# Val MAE: 0.16876991377423034
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 6/200
# Average train loss: -0.5146525470235008
# Average val loss: -0.5580012901533615
# Val MSE: 0.05593011846022765
# Val MAE: 0.16421854786107556
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 7/200
# Average train loss: -0.5300555935616383
# Average val loss: -0.5706258674415042
# Val MSE: 0.0554452669881414
# Val MAE: 0.16449409257296072
# Epoch 8/200
# Average train loss: -0.5423295638203073
# Average val loss: -0.5812955921165359
# Val MSE: 0.05613865916055825
# Val MAE: 0.16383595738027776
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 9/200
# Average train loss: -0.5524150433815637
# Average val loss: -0.5864250104588811
# Val MSE: 0.053906498071234606
# Val MAE: 0.1646834918872197
# Epoch 10/200
# Average train loss: -0.5610762919625282
# Average val loss: -0.5959024460408642
# Val MSE: 0.049944299561188975
# Val MAE: 0.15887611620257955
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 11/200
# Average train loss: -0.5693762465452291
# Average val loss: -0.6061088154903688
# Val MSE: 0.04914500774857864
# Val MAE: 0.1577646704358195
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 12/200
# Average train loss: -0.5767768642807002
# Average val loss: -0.5974533275444749
# Val MSE: 0.04670169110611107
# Val MAE: 0.15547199711489137
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 13/200
# Average train loss: -0.5832460794274976
# Average val loss: -0.6147289325058045
# Val MSE: 0.04904601279887913
# Val MAE: 0.15795440023654636
# Epoch 14/200
# Average train loss: -0.5883712711807184
# Average val loss: -0.6235799175112765
# Val MSE: 0.046737213526570114
# Val MAE: 0.15498287185948692
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 15/200
# Average train loss: -0.5937256099611862
# Average val loss: -0.6280240973730277
# Val MSE: 0.04556435059337432
# Val MAE: 0.1525924816818499
# Saved to ../my_models/ens_mc_dropout/member_8//best_model.pth
# Epoch 16/200
# Average train loss: -0.5980971432200282
# Average val loss: -0.6335630396750953
# Val MSE: 0.04584554568393876
# Val MAE: 0.15334416073763205
# Epoch 17/200
# Average train loss: -0.6011535871296645
# Average val loss: -0.6304960710577381
# Val MSE: 0.04812706390295165
# Val MAE: 0.1583691010582634
# Epoch 18/200
# Average train loss: -0.6063539707722669
# Average val loss: -0.6412501323981152
# Val MSE: 0.04580862899894991
# Val MAE: 0.15266955571203697
# Epoch 19/200
# Average train loss: -0.6073347715324564
# Average val loss: -0.6393733858487826
# Val MSE: 0.04748675288577347
# Val MAE: 0.15448325361005105
# Early stopping
# Epoch 0/200
# Average train loss: -0.09199102774311844
# Average val loss: -0.38354383310374485
# Val MSE: 0.062354828643155016
# Val MAE: 0.189600180367248
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 1/200
# Average train loss: -0.35626077093768
# Average val loss: -0.4484148630775018
# Val MSE: 0.05794468074907202
# Val MAE: 0.18057857326618054
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 2/200
# Average train loss: -0.4142994098850482
# Average val loss: -0.47752196501408306
# Val MSE: 0.05926292620352648
# Val MAE: 0.1794434581925437
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 3/200
# Average train loss: -0.4535131220629156
# Average val loss: -0.5070494022934279
# Val MSE: 0.056314364946139034
# Val MAE: 0.17514538495616422
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 4/200
# Average train loss: -0.48215676990335143
# Average val loss: -0.5364422894631373
# Val MSE: 0.05442133451526407
# Val MAE: 0.1680857522562406
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 5/200
# Average train loss: -0.5049640073492911
# Average val loss: -0.5524989408457113
# Val MSE: 0.05328284447220923
# Val MAE: 0.16597187476888142
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 6/200
# Average train loss: -0.520396934708208
# Average val loss: -0.5624870339389046
# Val MSE: 0.05301382575745497
# Val MAE: 0.16581699632445696
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 7/200
# Average train loss: -0.5346517378656951
# Average val loss: -0.5766673027229485
# Val MSE: 0.051641694995337765
# Val MAE: 0.16279661798856193
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 8/200
# Average train loss: -0.5475612521998164
# Average val loss: -0.5885877456185035
# Val MSE: 0.051345599788477976
# Val MAE: 0.16246046070723374
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 9/200
# Average train loss: -0.5564127666629202
# Average val loss: -0.5832882301382175
# Val MSE: 0.05163541466374119
# Val MAE: 0.16490313018759784
# Epoch 10/200
# Average train loss: -0.5668646740601622
# Average val loss: -0.6078644262088093
# Val MSE: 0.048186764984232626
# Val MAE: 0.1585079241634869
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 11/200
# Average train loss: -0.5743194448272255
# Average val loss: -0.6095261094046802
# Val MSE: 0.04540277815599137
# Val MAE: 0.15334378221179343
# Saved to ../my_models/ens_mc_dropout/member_9//best_model.pth
# Epoch 12/200
# Average train loss: -0.5814130275179221
# Average val loss: -0.6163457947156882
# Val MSE: 0.04741211367433547
# Val MAE: 0.1566643822834363
# Epoch 13/200
# Average train loss: -0.5864731867911948
# Average val loss: -0.6236565623055975
# Val MSE: 0.047968814286601304
# Val MAE: 0.15647795574434542
# Epoch 14/200
# Average train loss: -0.5928715962981752
# Average val loss: -0.6279978833002288
# Val MSE: 0.046531712826996884
# Val MAE: 0.15415760911092524
# Epoch 15/200
# Average train loss: -0.5971802260167391
# Average val loss: -0.6326502199034866
# Val MSE: 0.04671053799317066
# Val MAE: 0.15472630034314422
# Early stopping
# Epoch 0/200
# Average train loss: -0.06587860238751554
# Average val loss: -0.368938874794034
# Val MSE: 0.06283679679814946
# Val MAE: 0.19092785663097994
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 1/200
# Average train loss: -0.3623344138289364
# Average val loss: -0.4415355058750365
# Val MSE: 0.05858888849453799
# Val MAE: 0.1824985848227029
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 2/200
# Average train loss: -0.42485499810612737
# Average val loss: -0.4847333266104503
# Val MSE: 0.05404815647608312
# Val MAE: 0.17320301638792823
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 3/200
# Average train loss: -0.46201449729859345
# Average val loss: -0.5128007683714767
# Val MSE: 0.05241998817158363
# Val MAE: 0.16763325484683705
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 4/200
# Average train loss: -0.4885412219764689
# Average val loss: -0.5356840900817191
# Val MSE: 0.051743890038766095
# Val MAE: 0.16704537629276411
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 5/200
# Average train loss: -0.5092638166034513
# Average val loss: -0.5442999897472794
# Val MSE: 0.0543207588081511
# Val MAE: 0.17126781668656793
# Epoch 6/200
# Average train loss: -0.5274328616152093
# Average val loss: -0.5680232718165068
# Val MSE: 0.04983493974286323
# Val MAE: 0.16255573984170624
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 7/200
# Average train loss: -0.5388891050166975
# Average val loss: -0.5782219124471165
# Val MSE: 0.049936045964738475
# Val MAE: 0.16190975741564398
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 8/200
# Average train loss: -0.5495065634243049
# Average val loss: -0.586300097831009
# Val MSE: 0.05100981365055339
# Val MAE: 0.1632473314771565
# Epoch 9/200
# Average train loss: -0.5559404827960965
# Average val loss: -0.5935327774368044
# Val MSE: 0.05100930504418118
# Val MAE: 0.16220752508071243
# Epoch 10/200
# Average train loss: -0.5636213723575162
# Average val loss: -0.6011203084958763
# Val MSE: 0.04791589377558294
# Val MAE: 0.15741271661263517
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 11/200
# Average train loss: -0.569327673634398
# Average val loss: -0.60559998401392
# Val MSE: 0.050148664655663616
# Val MAE: 0.16179834342584376
# Epoch 12/200
# Average train loss: -0.5753332021597066
# Average val loss: -0.6067227118093689
# Val MSE: 0.04894602473318992
# Val MAE: 0.1596897212327669
# Epoch 13/200
# Average train loss: -0.582387363372041
# Average val loss: -0.6128898077621693
# Val MSE: 0.047136658465145774
# Val MAE: 0.1569691064478732
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 14/200
# Average train loss: -0.5871155404852731
# Average val loss: -0.6255165637285816
# Val MSE: 0.04681635330973083
# Val MAE: 0.15579449825430167
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 15/200
# Average train loss: -0.5925763209843163
# Average val loss: -0.6294464788850695
# Val MSE: 0.04686856835606777
# Val MAE: 0.15520528832431038
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 16/200
# Average train loss: -0.5963659647031203
# Average val loss: -0.6276371275084515
# Val MSE: 0.04602037693612368
# Val MAE: 0.15273755216380444
# Saved to ../my_models/ens_mc_dropout/member_10//best_model.pth
# Epoch 17/200
# Average train loss: -0.6023933951998731
# Average val loss: -0.6391367663950611
# Val MSE: 0.045957475576958645
# Val MAE: 0.15440595604946597
# Epoch 18/200
# Average train loss: -0.6053106950776231
# Average val loss: -0.6437083510227684
# Val MSE: 0.0460204245913644
# Val MAE: 0.1536803251385481
# Epoch 19/200
# Average train loss: -0.61005639537084
# Average val loss: -0.640951887827743
# Val MSE: 0.047610132651604735
# Val MAE: 0.1558026478135835
# Epoch 20/200
# Average train loss: -0.6144247519789572
# Average val loss: -0.6489374589252866
# Val MSE: 0.04616818437758405
# Val MAE: 0.15480481214717498
# Early stopping

# %% [markdown]
# # Learning curves

# %%
plot_learning_curve(history=models_hs,
                    metric="loss",
                    label="NLL",
                    ylims=(-1, 1.5))

# %%
plot_learning_curve(history=models_hs,
                    metric="mse",
                    label="MSE",
                    ylims=(0.01, 0.2))

# %%
plot_learning_curve(history=models_hs,
                    metric="mae",
                    label="MAE",
                    ylims=(0.1, 0.35))
